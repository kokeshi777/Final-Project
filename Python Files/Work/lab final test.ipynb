# %%
import pandas as pd

# %%
data=pd.read_csv('edited lines.csv')

# %%
data
# Out:
#              Date Home Team Away Team  Home Score  Away Score Playoff Game?  \
# 0      2021-02-07        TB        KC          31           9             Y
# 1      2021-01-24        KC       BUF          38          24             Y
# 2      2021-01-24        GB        TB          26          31             Y
# 3      2021-01-17        NO        TB          20          30             Y
# 4      2021-01-17        KC       CLE          22          17             Y
# ...           ...       ...       ...         ...         ...           ...
# 4002  2006 Week 1       DET       SEA           6           9           NaN
# 4003  2006 Week 1       CLE        NO          14          19           NaN
# 4004  2006 Week 1       CAR       ATL           6          20           NaN
# 4005  2006 Week 1       ARI        SF          34          27           NaN
# 4006  2006 Week 1       PIT       MIA          28          17           NaN
#
# ...

# %%
grouped = data.groupby(data.Date)

# %%
grouped

# %%
for i in range(2):
    week1 = grouped.get_group("2006 Week 1")

# %%
week1
# Out:
#              Date Home Team Away Team  Home Score  Away Score Playoff Game?  \
# 3990  2006 Week 1       ATL        TB          14           3           NaN
# 3991  2006 Week 1       WAS       MIN          16          19           NaN
# 3992  2006 Week 1       OAK        SD           0          27           NaN
# 3993  2006 Week 1       TEN       NYJ          16          23           NaN
# 3994  2006 Week 1        TB       BAL           0          27           NaN
# 3995  2006 Week 1       STL       DEN          18          10           NaN
# 3996  2006 Week 1       NYG       IND          21          26           NaN
# 3997  2006 Week 1        NE       BUF          19          17           NaN
# 3998  2006 Week 1        KC       CIN          10          23           NaN
# 3999  2006 Week 1       JAX       DAL          24          17           NaN
# 4000  2006 Week 1       HOU       PHI          10          24           NaN
# ...
